# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Import important libraries

# %%
import pandas as pd

# %% [markdown]
# # Read link-category data

# %%
links = pd.read_csv('/content/drive/MyDrive/Query-Search-LLM-Model/link_category.csv')

# %%
links.head()
# Out:
#                                                links    labels
# 0  https://www.flannels.com/cp-company-stretch-sa...  trousers
# 1  https://www.flannels.com/cp-company-ergonomic-...  trousers
# 2  https://www.flannels.com/stone-island-raso-car...  trousers
# 3  https://www.flannels.com/cp-company-lens-joggi...  trousers
# 4  https://www.flannels.com/fear-of-god-essential...  trousers

# %% [markdown]
# # Label values

# %%
links.labels.value_counts()
# Out:
# labels
# shoes                  4031
# jackets_coats          3688
# hoodies_sweatshirts    3194
# trousers               2109
# polo_shirts            1965
# shirts                 1835
# jeans                  1084
# knitwear                918
# leather_jackets          59
# Name: count, dtype: int64

# %%
links['links'][60]
# Out:
# 'https://www.flannels.com/polo-ralph-lauren-cuffed-logo-tech-jogging-bottoms-482110#colcode=48211021'

# %%
links.shape
# Out:
# (18883, 2)

# %% [markdown]
# # Define scrapping insights class

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import requests
from PIL import Image
import os
import time
import threading
from io import BytesIO

# %%
class ScrappingInsights:
    def __init__(self, links, image_save_dir="/content/drive/MyDrive/Query-Search-LLM-Model/images"):
        self.links = links
        self.image_save_dir = image_save_dir
        os.makedirs(image_save_dir, exist_ok=True)

    def get_soup(self, url):
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.198 Safari/537.36"
        }
        response = requests.get(url, headers=headers)
        soup = BeautifulSoup(response.text, 'html.parser')
        return soup

    def get_title(self, soup):
        title = soup.find('span', attrs={'id': 'lblProductName'})
        return title.text if title else np.nan

    def get_brand(self, soup):
        brand = soup.find('span', attrs={'id': 'lblProductBrand'})
        return brand.text.strip() if brand else np.nan

    def get_color(self, soup):
        color = soup.find('span', attrs={'id': 'colourName'})
        return color.text.strip() if color else np.nan

    def get_description(self, soup):
        description = soup.find('div', attrs={'class': 'infoPageDescription DisplayAttributesActive'})
        return description.text.strip() if description else np.nan

    def get_image_matrices(self, soup, category, idx):
        image_paths = []
        image_link_element = soup.find('div', attrs={'class': 'innerImageContainer swiper-wrapper'})
        if image_link_element:
            links = image_link_element.find_all('img')
            for i, link in enumerate(links):
                image_link = link['src']
                response = requests.get(image_link)
                img = Image.open(BytesIO(response.content))

                image_path = os.path.join(self.image_save_dir, f"{category}_{idx}_image_{i}.png")
                img.save(image_path)
                image_paths.append(image_path)
            return image_paths
        else:
            return np.nan

    def get_insights(self, category, rows):
        results = []
        for _, row in rows.iterrows():
            url = row['links']
            soup = self.get_soup(url)

            if soup:
                title = self.get_title(soup)
                brand = self.get_brand(soup)
                color = self.get_color(soup)
                description = self.get_description(soup)
                images = self.get_image_matrices(soup, category, idx=row.name)

                results.append({
                    'links': url,
                    'title': title,
                    'brand': brand,
                    'color': color,
                    'description': description,
                    'images': images
                })
        return pd.DataFrame(results)

    def threaded_processing(self, category):
        batch_size = 10
        data = self.links[self.links['labels'] == category].reset_index(drop=True)
        num_batches = (data.shape[0] + batch_size - 1) // batch_size
        results = []

        def thread_function(batch, batch_num):
            batch_results = self.get_insights(category, batch)
            results.append(batch_results)
            print(f"Processed batch {batch_num + 1}/{num_batches}")

        threads = []
        for i in range(num_batches):
            start_idx = i * batch_size
            end_idx = min((i + 1) * batch_size, data.shape[0])
            batch = data.iloc[start_idx:end_idx]

            thread = threading.Thread(target=thread_function, args=(batch, i))
            threads.append(thread)
            thread.start()

            if (i + 1) % batch_size == 0 or i == num_batches - 1:
                for thread in threads:
                    thread.join()
                threads = []

        processed_data = pd.concat(results, ignore_index=True)
        return processed_data

# %% [markdown]
# # Create object of scarpping insights

# %%
scrapping = ScrappingInsights(links)

# %% [markdown]
# # knitwear data

# %%
knitwear_data = scrapping.threaded_processing('knitwear')
# Out:
# Processed batch 2/92
# Processed batch 5/92
# Processed batch 3/92
# Processed batch 10/92
# Processed batch 1/92
# Processed batch 9/92
# Processed batch 6/92
# Processed batch 8/92
# Processed batch 4/92
# Processed batch 7/92
# Processed batch 18/92
# Processed batch 11/92
# Processed batch 20/92
# Processed batch 12/92
# Processed batch 13/92
# Processed batch 16/92
# Processed batch 19/92
# Processed batch 14/92
# Processed batch 17/92
# Processed batch 15/92
# Processed batch 30/92
# Processed batch 29/92
# Processed batch 26/92
# Processed batch 24/92
# Processed batch 27/92
# Processed batch 23/92
# Processed batch 22/92
# Processed batch 21/92
# Processed batch 28/92
# Processed batch 25/92
# Processed batch 32/92
# Processed batch 38/92
# Processed batch 37/92
# Processed batch 31/92
# Processed batch 35/92
# Processed batch 33/92
# Processed batch 34/92
# Processed batch 36/92
# Processed batch 40/92
# Processed batch 39/92
# Processed batch 48/92
# Processed batch 47/92
# Processed batch 41/92
# Processed batch 49/92
# Processed batch 42/92
# Processed batch 46/92
# Processed batch 43/92
# Processed batch 44/92
# Processed batch 45/92
# Processed batch 50/92
# Processed batch 54/92
# Processed batch 53/92
# Processed batch 55/92
# Processed batch 57/92
# Processed batch 52/92
# Processed batch 56/92
# Processed batch 60/92
# Processed batch 59/92
# Processed batch 58/92
# Processed batch 51/92
# Processed batch 66/92
# Processed batch 69/92
# Processed batch 65/92
# Processed batch 70/92
# Processed batch 61/92
# Processed batch 67/92
# Processed batch 62/92
# Processed batch 68/92
# Processed batch 64/92
# Processed batch 63/92
# Processed batch 77/92
# Processed batch 75/92
# Processed batch 80/92
# Processed batch 71/92
# Processed batch 76/92
# Processed batch 78/92
# Processed batch 74/92
# Processed batch 72/92
# Processed batch 73/92
# Processed batch 79/92
# Processed batch 88/92
# Processed batch 87/92
# Processed batch 84/92
# Processed batch 85/92
# Processed batch 82/92
# Processed batch 83/92
# Processed batch 86/92
# Processed batch 90/92
# Processed batch 81/92
# Processed batch 89/92
# Processed batch 92/92
# Processed batch 91/92

# %%
knitwear_data.to_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/knitwear_data', index=False)

# %% [markdown]
# # shoes data

# %%
shoes_data = scrapping.threaded_processing('shoes')
# Out:
# Processed batch 6/404
# Processed batch 3/404
# Processed batch 5/404
# Processed batch 1/404
# Processed batch 8/404
# Processed batch 2/404
# Processed batch 4/404
# Processed batch 7/404
# Processed batch 10/404
# Processed batch 17/369
# Processed batch 19/369
# Processed batch 13/369
# Processed batch 14/369
# Processed batch 11/369
# Processed batch 18/369
# Processed batch 20/369
# Processed batch 15/369
# Processed batch 25/369
# Processed batch 21/369
# Processed batch 23/369
# Processed batch 27/369
# Processed batch 22/369
# Processed batch 29/369
# Processed batch 30/369
# Processed batch 24/369
# Processed batch 26/369
# Processed batch 28/369
# Processed batch 39/369
# Processed batch 32/369
# Processed batch 38/369
# Processed batch 34/369
# Processed batch 35/369
# Processed batch 36/369
# Processed batch 40/369
# Processed batch 31/369
# Processed batch 33/369
# Processed batch 37/369
# Processed batch 49/369
# Processed batch 50/369
# Processed batch 41/369
# Processed batch 47/369
# Processed batch 48/369
# Processed batch 42/369
# Processed batch 44/369
# Processed batch 46/369
# Processed batch 45/369
# Processed batch 43/369
# Processed batch 55/369
# Processed batch 53/369
# Processed batch 54/369
# Processed batch 52/369
# Processed batch 60/369
# Processed batch 51/369
# Processed batch 57/369
# Processed batch 59/369
# Processed batch 58/369
# Processed batch 56/369
# Processed batch 61/369
# Processed batch 66/369
# Processed batch 63/369
# Processed batch 62/369
# Processed batch 64/369
# Processed batch 69/369
# Processed batch 65/369
# Processed batch 67/369
# Processed batch 70/369
# Processed batch 68/369
# Processed batch 75/369
# Processed batch 77/369
# Processed batch 72/369
# Processed batch 78/369
# Processed batch 74/369
# Processed batch 79/369
# Processed batch 80/369
# Processed batch 71/369
# Processed batch 73/369
# Processed batch 76/369
# Processed batch 86/369
# Processed batch 87/369
# Processed batch 90/369
# Processed batch 81/369
# Processed batch 82/369
# Processed batch 85/369
# Processed batch 89/369
# Processed batch 88/369
# Processed batch 83/369
# Processed batch 84/369
# Processed batch 98/369
# Processed batch 100/369
# Processed batch 99/369
# Processed batch 95/369
# Processed batch 97/369
# Processed batch 93/369
# Processed batch 94/369
# Processed batch 92/369
# Processed batch 91/369
# Processed batch 96/369
# Processed batch 106/369
# Processed batch 108/369
# Processed batch 101/369
# Processed batch 104/369
# Processed batch 103/369
# Processed batch 107/369
# Processed batch 109/369
# Processed batch 110/369
# Processed batch 105/369
# Processed batch 102/369
# Processed batch 112/369
# Processed batch 116/369
# Processed batch 118/369
# Processed batch 113/369
# Processed batch 119/369
# Processed batch 111/369
# Processed batch 117/369
# Processed batch 114/369
# Processed batch 120/369
# Processed batch 115/369
# Processed batch 126/369
# Processed batch 127/369
# Processed batch 125/369
# Processed batch 129/369
# Processed batch 124/369
# Processed batch 121/369
# Processed batch 130/369
# Processed batch 122/369
# Processed batch 128/369
# Processed batch 123/369
# Processed batch 140/369
# Processed batch 138/369
# Processed batch 139/369
# Processed batch 135/369
# Processed batch 137/369
# Processed batch 132/369
# Processed batch 134/369
# Processed batch 133/369
# Processed batch 136/369
# Processed batch 131/369
# Processed batch 146/369
# Processed batch 149/369
# Processed batch 148/369
# Processed batch 143/369
# Processed batch 144/369
# Processed batch 150/369
# Processed batch 145/369
# Processed batch 147/369
# Processed batch 141/369
# Processed batch 142/369
# Processed batch 158/369
# Processed batch 153/369
# Processed batch 152/369
# Processed batch 160/369
# Processed batch 154/369
# Processed batch 151/369
# Processed batch 155/369
# Processed batch 159/369
# Processed batch 156/369
# Processed batch 157/369
# Processed batch 162/369
# Processed batch 164/369
# Processed batch 161/369
# Processed batch 165/369
# Processed batch 168/369
# Processed batch 163/369
# Processed batch 169/369
# Processed batch 170/369
# Processed batch 167/369
# Processed batch 166/369
# Processed batch 179/369
# Processed batch 173/369
# Processed batch 177/369
# Processed batch 178/369
# Processed batch 175/369
# Processed batch 172/369
# Processed batch 174/369
# Processed batch 180/369
# Processed batch 176/369
# Processed batch 171/369
# Processed batch 182/369
# Processed batch 188/369
# Processed batch 187/369
# Processed batch 184/369
# Processed batch 186/369
# Processed batch 190/369
# Processed batch 183/369
# Processed batch 189/369
# Processed batch 185/369
# Processed batch 181/369
# Processed batch 192/369
# Processed batch 191/369
# Processed batch 193/369
# Processed batch 200/369
# Processed batch 195/369
# Processed batch 194/369
# Processed batch 197/369
# Processed batch 196/369
# Processed batch 198/369
# Processed batch 199/369
# Processed batch 204/369
# Processed batch 201/369
# Processed batch 210/369
# Processed batch 203/369
# Processed batch 208/369
# Processed batch 206/369
# Processed batch 209/369
# Processed batch 205/369
# Processed batch 207/369
# Processed batch 202/369
# Processed batch 214/369
# Processed batch 220/369
# Processed batch 211/369
# Processed batch 213/369
# Processed batch 216/369
# Processed batch 212/369
# Processed batch 215/369
# Processed batch 217/369
# Processed batch 218/369
# Processed batch 219/369
# Processed batch 227/369
# Processed batch 222/369
# Processed batch 224/369
# Processed batch 226/369
# Processed batch 223/369
# Processed batch 225/369
# Processed batch 221/369
# Processed batch 228/369
# Processed batch 230/369
# Processed batch 229/369
# Processed batch 231/369
# Processed batch 236/369
# Processed batch 238/369
# Processed batch 240/369
# Processed batch 239/369
# Processed batch 233/369
# Processed batch 234/369
# Processed batch 235/369
# Processed batch 232/369
# Processed batch 237/369
# Processed batch 247/369
# Processed batch 242/369
# Processed batch 245/369
# Processed batch 244/369
# Processed batch 250/369
# Processed batch 241/369
# Processed batch 246/369
# Processed batch 243/369
# Processed batch 248/369
# Processed batch 249/369
# Processed batch 254/369
# Processed batch 253/369
# Processed batch 257/369
# Processed batch 251/369
# Processed batch 258/369
# Processed batch 259/369
# Processed batch 256/369
# Processed batch 252/369
# Processed batch 260/369
# Processed batch 255/369
# Processed batch 270/369
# Processed batch 262/369
# Processed batch 264/369
# Processed batch 261/369
# Processed batch 266/369
# Processed batch 263/369
# Processed batch 269/369
# Processed batch 265/369
# Processed batch 268/369
# Processed batch 267/369
# Processed batch 278/369
# Processed batch 280/369
# Processed batch 277/369
# Processed batch 276/369
# Processed batch 279/369
# Processed batch 275/369
# Processed batch 271/369
# Processed batch 273/369
# Processed batch 274/369
# Processed batch 272/369
# Processed batch 288/369
# Processed batch 290/369
# Processed batch 283/369
# Processed batch 281/369
# Processed batch 289/369
# Processed batch 287/369
# Processed batch 285/369
# Processed batch 284/369
# Processed batch 282/369
# Processed batch 286/369
# Processed batch 295/369
# Processed batch 293/369
# Processed batch 298/369
# Processed batch 292/369
# Processed batch 300/369
# Processed batch 299/369
# Processed batch 294/369
# Processed batch 291/369
# Processed batch 297/369
# Processed batch 296/369
# Processed batch 301/369
# Processed batch 310/369
# Processed batch 307/369
# Processed batch 303/369
# Processed batch 305/369
# Processed batch 306/369
# Processed batch 309/369
# Processed batch 302/369
# Processed batch 304/369
# Processed batch 308/369
# Processed batch 319/369
# Processed batch 318/369
# Processed batch 320/369
# Processed batch 313/369
# Processed batch 311/369
# Processed batch 314/369
# Processed batch 312/369
# Processed batch 315/369
# Processed batch 317/369
# Processed batch 316/369
# Processed batch 327/369
# Processed batch 328/369
# Processed batch 329/369
# Processed batch 326/369
# Processed batch 323/369
# Processed batch 322/369
# Processed batch 321/369
# Processed batch 325/369
# Processed batch 330/369
# Processed batch 324/369
# Processed batch 333/369
# Processed batch 332/369
# Processed batch 340/369
# Processed batch 335/369
# Processed batch 331/369
# Processed batch 339/369
# Processed batch 336/369
# Processed batch 334/369
# Processed batch 337/369
# Processed batch 338/369
# Processed batch 341/369
# Processed batch 343/369
# Processed batch 345/369
# Processed batch 344/369
# Processed batch 348/369
# Processed batch 346/369
# Processed batch 342/369
# Processed batch 349/369
# Processed batch 347/369
# Processed batch 350/369
# Processed batch 357/369
# Processed batch 352/369
# Processed batch 355/369
# Processed batch 358/369
# Processed batch 356/369
# Processed batch 359/369
# Processed batch 354/369
# Processed batch 353/369
# Processed batch 351/369
# Processed batch 360/369
# Processed batch 363/369
# Processed batch 366/369
# Processed batch 369/369
# Processed batch 361/369
# Processed batch 364/369
# Processed batch 365/369
# Processed batch 368/369
# Processed batch 367/369
# Processed batch 362/369

# %%
jackets_coats_data.to_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/jackets_coats_data', index=False)

# %% [markdown]
# # hoodies_sweatshirts data

# %%
hoodies_sweatshirts_data = scrapping.threaded_processing('hoodies_sweatshirts')
# Out:
# Processed batch 6/320
# Processed batch 2/320
# Processed batch 4/320
# Processed batch 5/320
# Processed batch 7/320
# Processed batch 10/320
# Processed batch 1/320
# Processed batch 8/320
# Processed batch 9/320
# Processed batch 3/320
# Processed batch 18/320
# Processed batch 20/320
# Processed batch 15/320
# Processed batch 11/320
# Processed batch 12/320
# Processed batch 17/320
# Processed batch 14/320
# Processed batch 16/320
# Processed batch 13/320
# Processed batch 19/320
# Processed batch 23/320
# Processed batch 24/320
# Processed batch 27/320
# Processed batch 21/320
# Processed batch 30/320
# Processed batch 22/320
# Processed batch 28/320
# Processed batch 25/320
# Processed batch 29/320
# Processed batch 26/320
# Processed batch 34/320
# Processed batch 37/320
# Processed batch 31/320
# Processed batch 40/320
# Processed batch 33/320
# Processed batch 38/320
# Processed batch 36/320
# Processed batch 39/320
# Processed batch 32/320
# Processed batch 35/320
# Processed batch 43/320
# Processed batch 45/320
# Processed batch 42/320
# Processed batch 44/320
# Processed batch 50/320
# Processed batch 48/320
# Processed batch 49/320
# Processed batch 47/320
# Processed batch 181/320
# Processed batch 188/320
# Processed batch 189/320
# Processed batch 184/320
# Processed batch 195/320
# Processed batch 196/320
# Processed batch 194/320
# Processed batch 191/320
# Processed batch 193/320
# Processed batch 199/320
# Processed batch 197/320
# Processed batch 200/320
# Processed batch 192/320
# Processed batch 198/320
# Processed batch 204/320
# Processed batch 205/320
# Processed batch 206/320
# Processed batch 203/320
# Processed batch 207/320
# Processed batch 202/320
# Processed batch 208/320
# Processed batch 209/320
# Processed batch 210/320
# Processed batch 201/320
# Processed batch 211/320
# Processed batch 214/320
# Processed batch 220/320
# Processed batch 212/320
# Processed batch 216/320
# Processed batch 213/320
# Processed batch 217/320
# Processed batch 218/320
# Processed batch 219/320
# Processed batch 215/320
# Processed batch 227/320
# Processed batch 226/320
# Processed batch 230/320
# Processed batch 223/320
# Processed batch 229/320
# Processed batch 221/320
# Processed batch 225/320
# Processed batch 222/320
# Processed batch 228/320
# Processed batch 224/320
# Processed batch 239/320
# Processed batch 233/320
# Processed batch 240/320
# Processed batch 238/320
# Processed batch 234/320
# Processed batch 236/320
# Processed batch 237/320
# Processed batch 231/320
# Processed batch 235/320
# Processed batch 232/320
# Processed batch 245/320
# Processed batch 241/320
# Processed batch 247/320
# Processed batch 243/320
# Processed batch 242/320
# Processed batch 249/320
# Processed batch 246/320
# Processed batch 244/320
# Processed batch 248/320
# Processed batch 250/320
# Processed batch 252/320
# Processed batch 259/320
# Processed batch 253/320
# Processed batch 254/320
# Processed batch 257/320
# Processed batch 251/320
# Processed batch 258/320
# Processed batch 255/320
# Processed batch 256/320
# Processed batch 260/320
# Processed batch 262/320
# Processed batch 269/320
# Processed batch 261/320
# Processed batch 268/320
# Processed batch 266/320
# Processed batch 270/320
# Processed batch 263/320
# Processed batch 265/320
# Processed batch 267/320
# Processed batch 264/320
# Processed batch 279/320
# Processed batch 278/320
# Processed batch 275/320
# Processed batch 274/320
# Processed batch 277/320
# Processed batch 272/320
# Processed batch 280/320
# Processed batch 276/320
# Processed batch 273/320
# Processed batch 271/320
# Processed batch 287/320
# Processed batch 289/320
# Processed batch 285/320
# Processed batch 288/320
# Processed batch 290/320
# Processed batch 286/320
# Processed batch 283/320
# Processed batch 281/320
# Processed batch 282/320
# Processed batch 284/320
# Processed batch 292/320
# Processed batch 294/320
# Processed batch 300/320
# Processed batch 297/320
# Processed batch 299/320
# Processed batch 295/320
# Processed batch 293/320
# Processed batch 291/320
# Processed batch 296/320
# Processed batch 298/320
# Processed batch 303/320
# Processed batch 304/320
# Processed batch 302/320
# Processed batch 305/320
# Processed batch 308/320
# Processed batch 306/320
# Processed batch 310/320
# Processed batch 301/320
# Processed batch 309/320
# Processed batch 307/320
# Processed batch 320/320
# Processed batch 313/320
# Processed batch 311/320
# Processed batch 314/320
# Processed batch 317/320
# Processed batch 312/320
# Processed batch 315/320
# Processed batch 316/320
# Processed batch 318/320
# Processed batch 319/320

# %%
hoodies_sweatshirts_data.to_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/hoodies_sweatshirts_data', index=False)

# %% [markdown]
# # Trousers data

# %%
trousers_data = scrapping.threaded_processing('trousers')
# Out:
# Processed batch 9/211
# Processed batch 2/211
# Processed batch 3/211
# Processed batch 1/211
# Processed batch 4/211
# Processed batch 5/211
# Processed batch 10/211
# Processed batch 8/211
# Processed batch 7/211
# Processed batch 6/211
# Processed batch 14/211
# Processed batch 18/211
# Processed batch 11/211
# Processed batch 13/211
# Processed batch 12/211
# Processed batch 16/211
# Processed batch 19/211
# Processed batch 17/211
# Processed batch 15/211
# Processed batch 20/211
# Processed batch 28/211
# Processed batch 26/211
# Processed batch 23/211
# Processed batch 22/211
# Processed batch 25/211
# Processed batch 30/211
# Processed batch 21/211
# Processed batch 29/211
# Processed batch 27/211
# Processed batch 24/211
# Processed batch 32/211
# Processed batch 35/211
# Processed batch 40/211
# Processed batch 34/211
# Processed batch 37/211
# Processed batch 38/211
# Processed batch 31/211
# Processed batch 33/211
# Processed batch 36/211
# Processed batch 39/211
# Processed batch 41/211
# Processed batch 44/211
# Processed batch 49/211
# Processed batch 42/211
# Processed batch 50/211
# Processed batch 45/211
# Processed batch 48/211
# Processed batch 47/211
# Processed batch 43/211
# Processed batch 46/211
# Processed batch 55/211
# Processed batch 57/211
# Processed batch 51/211
# Processed batch 60/211
# Processed batch 54/211
# Processed batch 59/211
# Processed batch 53/211
# Processed batch 56/211
# Processed batch 52/211
# Processed batch 58/211
# Processed batch 70/211
# Processed batch 63/211
# Processed batch 62/211
# Processed batch 66/211
# Processed batch 68/211
# Processed batch 67/211
# Processed batch 64/211
# Processed batch 65/211
# Processed batch 61/211
# Processed batch 69/211
# Processed batch 71/211
# Processed batch 78/211
# Processed batch 76/211
# Processed batch 75/211
# Processed batch 73/211
# Processed batch 79/211
# Processed batch 80/211
# Processed batch 74/211
# Processed batch 72/211
# Processed batch 77/211
# Processed batch 84/211
# Processed batch 90/211
# Processed batch 83/211
# Processed batch 89/211
# Processed batch 85/211
# Processed batch 87/211
# Processed batch 82/211
# Processed batch 81/211
# Processed batch 88/211
# Processed batch 86/211
# Processed batch 99/211
# Processed batch 91/211
# Processed batch 93/211
# Processed batch 94/211
# Processed batch 92/211
# Processed batch 95/211
# Processed batch 98/211
# Processed batch 100/211
# Processed batch 97/211
# Processed batch 96/211
# Processed batch 108/211
# Processed batch 109/211
# Processed batch 107/211
# Processed batch 101/211
# Processed batch 102/211
# Processed batch 110/211
# Processed batch 104/211
# Processed batch 103/211
# Processed batch 105/211
# Processed batch 106/211
# Processed batch 113/211
# Processed batch 115/211
# Processed batch 111/211
# Processed batch 120/211
# Processed batch 116/211
# Processed batch 118/211
# Processed batch 112/211
# Processed batch 117/211
# Processed batch 119/211
# Processed batch 114/211
# Processed batch 125/211
# Processed batch 127/211
# Processed batch 129/211
# Processed batch 126/211
# Processed batch 124/211
# Processed batch 121/211
# Processed batch 130/211
# Processed batch 122/211
# Processed batch 128/211
# Processed batch 123/211
# Processed batch 137/211
# Processed batch 138/211
# Processed batch 134/211
# Processed batch 133/211
# Processed batch 139/211
# Processed batch 136/211
# Processed batch 132/211
# Processed batch 140/211
# Processed batch 131/211
# Processed batch 135/211
# Processed batch 142/211
# Processed batch 150/211
# Processed batch 145/211
# Processed batch 149/211
# Processed batch 141/211
# Processed batch 148/211
# Processed batch 147/211
# Processed batch 146/211
# Processed batch 143/211
# Processed batch 144/211
# Processed batch 158/211
# Processed batch 156/211
# Processed batch 155/211
# Processed batch 157/211
# Processed batch 154/211
# Processed batch 152/211
# Processed batch 159/211
# Processed batch 160/211
# Processed batch 151/211
# Processed batch 153/211
# Processed batch 165/211
# Processed batch 162/211
# Processed batch 167/211
# Processed batch 166/211
# Processed batch 163/211
# Processed batch 169/211
# Processed batch 161/211
# Processed batch 168/211
# Processed batch 170/211
# Processed batch 164/211
# Processed batch 173/211
# Processed batch 178/211
# Processed batch 179/211
# Processed batch 177/211
# Processed batch 180/211
# Processed batch 171/211
# Processed batch 172/211
# Processed batch 175/211
# Processed batch 174/211
# Processed batch 176/211
# Processed batch 183/211
# Processed batch 182/211
# Processed batch 189/211
# Processed batch 188/211
# Processed batch 187/211
# Processed batch 185/211
# Processed batch 181/211
# Processed batch 186/211
# Processed batch 184/211
# Processed batch 190/211
# Processed batch 192/211
# Processed batch 200/211
# Processed batch 196/211
# Processed batch 193/211
# Processed batch 198/211
# Processed batch 197/211
# Processed batch 195/211
# Processed batch 199/211
# Processed batch 191/211
# Processed batch 194/211
# Processed batch 206/211
# Processed batch 210/211
# Processed batch 203/211
# Processed batch 208/211
# Processed batch 204/211
# Processed batch 209/211
# Processed batch 202/211
# Processed batch 207/211
# Processed batch 205/211
# Processed batch 201/211
# Processed batch 211/211

# %%
trousers_data.to_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/trousers_data', index=False)

# %% [markdown]
# # polo_shirts data

# %%
polo_shirts_data = scrapping.threaded_processing('polo_shirts')
# Out:
# Processed batch 10/197
# Processed batch 1/197
# Processed batch 4/197
# Processed batch 9/197
# Processed batch 2/197
# Processed batch 5/197
# Processed batch 6/197
# Processed batch 3/197
# Processed batch 8/197
# Processed batch 7/197
# Processed batch 11/197
# Processed batch 13/197
# Processed batch 17/197
# Processed batch 12/197
# Processed batch 15/197
# Processed batch 19/197
# Processed batch 16/197
# Processed batch 20/197
# Processed batch 14/197
# Processed batch 18/197
# Processed batch 24/197
# Processed batch 28/197
# Processed batch 29/197
# Processed batch 21/197
# Processed batch 22/197
# Processed batch 26/197
# Processed batch 27/197
# Processed batch 23/197
# Processed batch 25/197
# Processed batch 30/197
# Processed batch 37/197
# Processed batch 31/197
# Processed batch 36/197
# Processed batch 34/197
# Processed batch 39/197
# Processed batch 32/197
# Processed batch 35/197
# Processed batch 40/197
# Processed batch 38/197
# Processed batch 33/197
# Processed batch 44/197
# Processed batch 43/197
# Processed batch 48/197
# Processed batch 49/197
# Processed batch 46/197
# Processed batch 47/197
# Processed batch 45/197
# Processed batch 50/197
# Processed batch 41/197
# Processed batch 42/197
# Processed batch 51/197
# Processed batch 55/197
# Processed batch 60/197
# Processed batch 56/197
# Processed batch 57/197
# Processed batch 53/197
# Processed batch 59/197
# Processed batch 54/197
# Processed batch 58/197
# Processed batch 52/197
# Processed batch 68/197
# Processed batch 69/197
# Processed batch 67/197
# Processed batch 63/197
# Processed batch 64/197
# Processed batch 62/197
# Processed batch 65/197
# Processed batch 61/197
# Processed batch 70/197
# Processed batch 66/197
# Processed batch 79/197
# Processed batch 71/197
# Processed batch 72/197
# Processed batch 77/197
# Processed batch 80/197
# Processed batch 75/197
# Processed batch 76/197
# Processed batch 74/197
# Processed batch 73/197
# Processed batch 78/197
# Processed batch 88/197
# Processed batch 86/197
# Processed batch 83/197
# Processed batch 82/197
# Processed batch 90/197
# Processed batch 89/197
# Processed batch 87/197
# Processed batch 85/197
# Processed batch 84/197
# Processed batch 81/197
# Processed batch 96/197
# Processed batch 91/197
# Processed batch 94/197
# Processed batch 99/197
# Processed batch 97/197
# Processed batch 95/197
# Processed batch 100/197
# Processed batch 93/197
# Processed batch 98/197
# Processed batch 92/197
# Processed batch 103/197
# Processed batch 106/197
# Processed batch 109/197
# Processed batch 107/197
# Processed batch 104/197
# Processed batch 110/197
# Processed batch 101/197
# Processed batch 102/197
# Processed batch 105/197
# Processed batch 108/197
# Processed batch 115/197
# Processed batch 119/197
# Processed batch 113/197
# Processed batch 116/197
# Processed batch 118/197
# Processed batch 120/197
# Processed batch 111/197
# Processed batch 114/197
# Processed batch 112/197
# Processed batch 117/197
# Processed batch 126/197
# Processed batch 124/197
# Processed batch 123/197
# Processed batch 128/197
# Processed batch 122/197
# Processed batch 121/197
# Processed batch 125/197
# Processed batch 129/197
# Processed batch 130/197
# Processed batch 127/197
# Processed batch 131/197
# Processed batch 136/197
# Processed batch 133/197
# Processed batch 135/197
# Processed batch 132/197
# Processed batch 139/197
# Processed batch 137/197
# Processed batch 138/197
# Processed batch 134/197
# Processed batch 140/197
# Processed batch 141/197
# Processed batch 144/197
# Processed batch 142/197
# Processed batch 148/197
# Processed batch 145/197
# Processed batch 146/197
# Processed batch 143/197
# Processed batch 150/197
# Processed batch 147/197
# Processed batch 149/197
# Processed batch 157/197
# Processed batch 156/197
# Processed batch 159/197
# Processed batch 154/197
# Processed batch 151/197
# Processed batch 160/197
# Processed batch 153/197
# Processed batch 152/197
# Processed batch 158/197
# Processed batch 155/197
# Processed batch 161/197
# Processed batch 168/197
# Processed batch 162/197
# Processed batch 167/197
# Processed batch 166/197
# Processed batch 164/197
# Processed batch 165/197
# Processed batch 169/197
# Processed batch 163/197
# Processed batch 170/197
# Processed batch 174/197
# Processed batch 180/197
# Processed batch 172/197
# Processed batch 179/197
# Processed batch 171/197
# Processed batch 177/197
# Processed batch 173/197
# Processed batch 175/197
# Processed batch 176/197
# Processed batch 178/197
# Processed batch 184/197
# Processed batch 190/197
# Processed batch 183/197
# Processed batch 182/197
# Processed batch 189/197
# Processed batch 181/197
# Processed batch 188/197
# Processed batch 185/197
# Processed batch 187/197
# Processed batch 186/197
# Processed batch 197/197
# Processed batch 191/197
# Processed batch 192/197
# Processed batch 195/197
# Processed batch 194/197
# Processed batch 193/197
# Processed batch 196/197

# %%
polo_shirts_data.to_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/polo_shirts_data', index=False)

# %% [markdown]
# # shirts data

# %%
shirts_data = scrapping.threaded_processing('shirts')
# Out:
# Processed batch 1/184
# Processed batch 2/184
# Processed batch 7/184
# Processed batch 9/184
# Processed batch 6/184
# Processed batch 3/184
# Processed batch 4/184
# Processed batch 8/184
# Processed batch 10/184
# Processed batch 5/184
# Processed batch 19/184
# Processed batch 12/184
# Processed batch 18/184
# Processed batch 17/184
# Processed batch 13/184
# Processed batch 11/184
# Processed batch 16/184
# Processed batch 14/184
# Processed batch 20/184
# Processed batch 15/184
# Processed batch 27/184
# Processed batch 25/184
# Processed batch 24/184
# Processed batch 28/184
# Processed batch 30/184
# Processed batch 23/184
# Processed batch 21/184
# Processed batch 22/184
# Processed batch 29/184
# Processed batch 26/184
# Processed batch 37/184
# Processed batch 38/184
# Processed batch 33/184
# Processed batch 40/184
# Processed batch 34/184
# Processed batch 35/184
# Processed batch 31/184
# Processed batch 32/184
# Processed batch 36/184
# Processed batch 39/184
# Processed batch 50/184
# Processed batch 45/184
# Processed batch 48/184
# Processed batch 42/184
# Processed batch 47/184
# Processed batch 41/184
# Processed batch 43/184
# Processed batch 46/184
# Processed batch 49/184
# Processed batch 44/184
# Processed batch 58/184
# Processed batch 53/184
# Processed batch 57/184
# Processed batch 52/184
# Processed batch 55/184
# Processed batch 56/184
# Processed batch 51/184
# Processed batch 59/184
# Processed batch 60/184
# Processed batch 54/184
# Processed batch 66/184
# Processed batch 70/184
# Processed batch 61/184
# Processed batch 65/184
# Processed batch 67/184
# Processed batch 64/184
# Processed batch 63/184
# Processed batch 68/184
# Processed batch 69/184
# Processed batch 62/184
# Processed batch 78/184
# Processed batch 76/184
# Processed batch 80/184
# Processed batch 75/184
# Processed batch 74/184
# Processed batch 72/184
# Processed batch 71/184
# Processed batch 73/184
# Processed batch 77/184
# Processed batch 79/184
# Processed batch 82/184
# Processed batch 87/184
# Processed batch 85/184
# Processed batch 88/184
# Processed batch 81/184
# Processed batch 86/184
# Processed batch 84/184
# Processed batch 89/184
# Processed batch 83/184
# Processed batch 90/184
# Processed batch 98/184
# Processed batch 91/184
# Processed batch 96/184
# Processed batch 94/184
# Processed batch 99/184
# Processed batch 97/184
# Processed batch 95/184
# Processed batch 93/184
# Processed batch 100/184
# Processed batch 92/184
# Processed batch 107/184
# Processed batch 105/184
# Processed batch 108/184
# Processed batch 104/184
# Processed batch 102/184
# Processed batch 101/184
# Processed batch 106/184
# Processed batch 103/184
# Processed batch 109/184
# Processed batch 110/184
# Processed batch 111/184
# Processed batch 113/184
# Processed batch 120/184
# Processed batch 114/184
# Processed batch 119/184
# Processed batch 117/184
# Processed batch 115/184
# Processed batch 116/184
# Processed batch 118/184
# Processed batch 112/184
# Processed batch 128/184
# Processed batch 121/184
# Processed batch 126/184
# Processed batch 129/184
# Processed batch 130/184
# Processed batch 124/184
# Processed batch 127/184
# Processed batch 123/184
# Processed batch 125/184
# Processed batch 122/184
# Processed batch 136/184
# Processed batch 140/184
# Processed batch 134/184
# Processed batch 139/184
# Processed batch 132/184
# Processed batch 135/184
# Processed batch 133/184
# Processed batch 138/184
# Processed batch 137/184
# Processed batch 131/184
# Processed batch 149/184
# Processed batch 143/184
# Processed batch 141/184
# Processed batch 146/184
# Processed batch 144/184
# Processed batch 148/184
# Processed batch 145/184
# Processed batch 147/184
# Processed batch 142/184
# Processed batch 150/184
# Processed batch 158/184
# Processed batch 155/184
# Processed batch 156/184
# Processed batch 151/184
# Processed batch 159/184
# Processed batch 160/184
# Processed batch 153/184
# Processed batch 154/184
# Processed batch 157/184
# Processed batch 152/184
# Processed batch 168/184
# Processed batch 163/184
# Processed batch 161/184
# Processed batch 162/184
# Processed batch 165/184
# Processed batch 169/184
# Processed batch 164/184
# Processed batch 166/184
# Processed batch 170/184
# Processed batch 167/184
# Processed batch 172/184
# Processed batch 178/184
# Processed batch 174/184
# Processed batch 175/184
# Processed batch 176/184
# Processed batch 171/184
# Processed batch 179/184
# Processed batch 177/184
# Processed batch 180/184
# Processed batch 173/184
# Processed batch 184/184
# Processed batch 181/184
# Processed batch 183/184
# Processed batch 182/184

# %%
shirts_data.to_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/shirts_data', index=False)

# %% [markdown]
# # Jeans data

# %%
jeans_data = scrapping.threaded_processing('jeans')
# Out:
# Processed batch 7/109
# Processed batch 10/109
# Processed batch 9/109
# Processed batch 8/109
# Processed batch 1/109
# Processed batch 6/109
# Processed batch 3/109
# Processed batch 2/109
# Processed batch 5/109
# Processed batch 4/109
# Processed batch 13/109
# Processed batch 11/109
# Processed batch 14/109
# Processed batch 20/109
# Processed batch 17/109
# Processed batch 15/109
# Processed batch 16/109
# Processed batch 19/109
# Processed batch 18/109
# Processed batch 12/109
# Processed batch 27/109
# Processed batch 22/109
# Processed batch 21/109
# Processed batch 30/109
# Processed batch 28/109
# Processed batch 25/109
# Processed batch 29/109
# Processed batch 24/109
# Processed batch 23/109
# Processed batch 26/109
# Processed batch 35/109
# Processed batch 40/109
# Processed batch 36/109
# Processed batch 31/109
# Processed batch 38/109
# Processed batch 34/109
# Processed batch 37/109
# Processed batch 33/109
# Processed batch 32/109
# Processed batch 39/109
# Processed batch 46/109
# Processed batch 41/109
# Processed batch 43/109
# Processed batch 42/109
# Processed batch 44/109
# Processed batch 45/109
# Processed batch 49/109
# Processed batch 48/109
# Processed batch 47/109
# Processed batch 50/109
# Processed batch 55/109
# Processed batch 58/109
# Processed batch 52/109
# Processed batch 60/109
# Processed batch 57/109
# Processed batch 59/109
# Processed batch 53/109
# Processed batch 51/109
# Processed batch 54/109
# Processed batch 56/109
# Processed batch 62/109
# Processed batch 67/109
# Processed batch 61/109
# Processed batch 64/109
# Processed batch 68/109
# Processed batch 65/109
# Processed batch 70/109
# Processed batch 66/109
# Processed batch 63/109
# Processed batch 69/109
# Processed batch 79/109
# Processed batch 77/109
# Processed batch 78/109
# Processed batch 80/109
# Processed batch 76/109
# Processed batch 75/109
# Processed batch 72/109
# Processed batch 73/109
# Processed batch 71/109
# Processed batch 74/109
# Processed batch 86/109
# Processed batch 88/109
# Processed batch 82/109
# Processed batch 90/109
# Processed batch 83/109
# Processed batch 87/109
# Processed batch 84/109
# Processed batch 81/109
# Processed batch 85/109
# Processed batch 89/109
# Processed batch 99/109
# Processed batch 100/109
# Processed batch 93/109
# Processed batch 94/109
# Processed batch 97/109
# Processed batch 98/109
# Processed batch 95/109
# Processed batch 96/109
# Processed batch 91/109
# Processed batch 92/109
# Processed batch 109/109
# Processed batch 102/109
# Processed batch 106/109
# Processed batch 101/109
# Processed batch 107/109
# Processed batch 103/109
# Processed batch 108/109
# Processed batch 105/109
# Processed batch 104/109

# %%
jeans_data.to_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/jeans_data', index=False)

# %% [markdown]
# # Leather_jackets data

# %%
leather_jackets_data = scrapping.threaded_processing('leather_jackets')
# Out:
# Processed batch 6/6
# Processed batch 2/6
# Processed batch 5/6
# Processed batch 1/6
# Processed batch 3/6
# Processed batch 4/6

# %%
leather_jackets_data.to_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/leather_jackets_data', index=False)

# %% [markdown]
# # Incorporate all data into one

# %%
knitwear_data = pd.read_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/knitwear_data')
shoes_data = pd.read_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/shoes_data')
jackets_coats_data = pd.read_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/jackets_coats_data')
hoodies_sweatshirts_data = pd.read_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/hoodies_sweatshirts_data')
trousers_data = pd.read_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/trousers_data')
polo_shirts_data = pd.read_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/polo_shirts_data')
shirts_data = pd.read_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/shirts_data')
jeans_data = pd.read_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/jeans_data')
leather_jackets_data = pd.read_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/leather_jackets_data')

# %%
knitwear_data['category'] = 'knitwear'
shoes_data['category'] = 'shoes'
jackets_coats_data['category'] = 'jackets_coats'
hoodies_sweatshirts_data['category'] = 'hoodies_sweatshirts'
trousers_data['category'] = 'trousers'
polo_shirts_data['category'] = 'polo_shirts'
shirts_data['category'] = 'shirts'
jeans_data['category'] = 'jeans'
leather_jackets_data['category'] = 'leather_jackets'

# %%
final_data = pd.concat([knitwear_data, shoes_data, jackets_coats_data, hoodies_sweatshirts_data, trousers_data, polo_shirts_data, shirts_data, jeans_data, leather_jackets_data], ignore_index=True)

# %%
final_data.shape
# Out:
# (18883, 7)

# %%
final_data.to_parquet('/content/drive/MyDrive/Query-Search-LLM-Model/all_data', index=False)
